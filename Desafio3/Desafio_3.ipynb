# %% [markdown]
# ## Desafio 3 da Trilha de Visão Computacional
#
# Rastreamento de objetos
#
# Aluna: Liah Colins

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install ultralytics opencv-python torch
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.83-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: opencv-python in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.13.0.92)
# Collecting torch
#   Using cached torch-2.12.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ultralytics) (3.11.0)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ultralytics) (2.34.2)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.27.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\liahc\AppData\Roaming\Python\Python311\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.42.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.29.4-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\liahc\AppData\Roaming\Python\Python311\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch) (65.5.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\liahc\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\liahc\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.42.0 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.42.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\liahc\AppData\Roaming\Python\Python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\liahc\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading ultralytics-8.4.83-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 6.9 MB/s  0:00:00
# Using cached torch-2.12.1-cp311-cp311-win_amd64.whl (123.0 MB)
# Using cached fsspec-2026.6.0-py3-none-any.whl (203 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading polars-1.42.0-py3-none-any.whl (836 kB)
#    ---------------------------------------- 0.0/836.9 kB ? eta -:--:--
#    ---------------------------------------- 836.9/836.9 kB ?  0:00:00
# Downloading polars_runtime_32-1.42.0-cp310-abi3-win_amd64.whl (52.7 MB)
#    ---------------------------------------- 0.0/52.7 MB ? eta -:--:--
#    ---- ----------------------------------- 5.5/52.7 MB 28.0 MB/s eta 0:00:02
#    -------- ------------------------------- 11.5/52.7 MB 27.8 MB/s eta 0:00:02
#    ------------- -------------------------- 17.6/52.7 MB 28.4 MB/s eta 0:00:02
#    ------------------ --------------------- 24.6/52.7 MB 30.0 MB/s eta 0:00:01
#    ------------------------ --------------- 32.0/52.7 MB 31.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 39.3/52.7 MB 32.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 46.4/52.7 MB 32.4 MB/s eta 0:00:01
#    ---------------------------------------  52.7/52.7 MB 32.0 MB/s eta 0:00:01
#    ---------------------------------------- 52.7/52.7 MB 31.1 MB/s  0:00:01
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached torchvision-0.27.1-cp311-cp311-win_amd64.whl (3.8 MB)
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Using cached filelock-3.29.4-py3-none-any.whl (42 kB)
# Installing collected packages: nvidia-ml-py, mpmath, sympy, polars-runtime-32, networkx, fsspec, filelock, torch, polars, ultralytics-thop, torchvision, ultralytics
#
#    --- ------------------------------------  1/12 [mpmath]
#    --- ------------------------------------  1/12 [mpmath]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ---------- -----------------------------  3/12 [polars-runtime-32]
#    ---------- -----------------------------  3/12 [polars-runtime-32]
#    ---------- -----------------------------  3/12 [polars-runtime-32]
#    ---------- -----------------------------  3/12 [polars-runtime-32]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ------------- --------------------------  4/12 [networkx]
#    ---------------- -----------------------  5/12 [fsspec]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    ----------------------- ----------------  7/12 [torch]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    -------------------------- -------------  8/12 [polars]
#    --------------------------------- ------ 10/12 [torchvision]
#    --------------------------------- ------ 10/12 [torchvision]
#    --------------------------------- ------ 10/12 [torchvision]
#    --------------------------------- ------ 10/12 [torchvision]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ------------------------------------ --- 11/12 [ultralytics]
#    ---------------------------------------- 12/12 [ultralytics]
#
# Successfully installed filelock-3.29.4 fsspec-2026.6.0 mpmath-1.3.0 networkx-3.6.1 nvidia-ml-py-13.610.43 polars-1.42.0 polars-runtime-32-1.42.0 sympy-1.14.0 torch-2.12.1 torchvision-0.27.1 ultralytics-8.4.83 ultralytics-thop-2.0.20

# %%
import ultralytics
import cv2
import torch

# %% [markdown]
# ### Processar dados

# %%
model = ultralytics.YOLO("yolo11n.pt")

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device
239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 59.1ms
# video 1/1 (frame 214/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 57.7ms
# video 1/1 (frame 215/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 61.8ms
# video 1/1 (frame 216/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 2 oranges, 58.7ms
# video 1/1 (frame 217/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 2 oranges, 64.0ms
# video 1/1 (frame 218/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 3 oranges, 59.0ms
# video 1/1 (frame 219/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 60.3ms
# video 1/1 (frame 220/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 3 oranges, 61.2ms
# video 1/1 (frame 221/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 3 oranges, 60.1ms
# video 1/1 (frame 222/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 3 oranges, 61.2ms
# video 1/1 (frame 223/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 1 apple, 3 oranges, 60.7ms
# video 1/1 (frame 224/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 59.7ms
# video 1/1 (frame 225/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 61.1ms
# video 1/1 (frame 226/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 61.1ms
# video 1/1 (frame 227/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 61.4ms
# video 1/1 (frame 228/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 3 oranges, 61.7ms
# video 1/1 (frame 229/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 59.7ms
# video 1/1 (frame 230/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 60.9ms
# video 1/1 (frame 231/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 3 apples, 2 oranges, 62.5ms
# video 1/1 (frame 232/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 3 apples, 2 oranges, 61.1ms
# video 1/1 (frame 233/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 3 apples, 2 oranges, 60.0ms
# video 1/1 (frame 234/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 3 apples, 2 oranges, 59.2ms
# video 1/1 (frame 235/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 59.9ms
# video 1/1 (frame 236/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 59.2ms
# video 1/1 (frame 237/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 59.3ms
# video 1/1 (frame 238/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 57.7ms
# video 1/1 (frame 239/239) c:\Liah\Nexvisual\Desafios\Desafio3\video.mov: 384x640 2 apples, 2 oranges, 60.2ms
# Speed: 1.6ms preprocess, 60.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Salvar Vídeo

# %%
for r in results:
    print(r)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 26, 133, 205],
#         [ 27, 134, 206],
#         [ 27, 134, 206]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 23, 130, 202],
#         [ 25, 132, 204],
#         [ 25, 132, 204]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 22, 129, 201],
#         [ 21, 128, 200],
#         [ 20, 127, 199]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 2.249500001198612, 'inference': 68.38770000103978, 'postprocess': 1.0318000004190253}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 26, 133, 205],
#         [ 27, 134, 206],
#         [ 27, 134, 206]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 23, 130, 202],
#         [ 25, 132, 204],
#         [ 25, 132, 204]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 22, 129, 201],
#         [ 21, 128, 200],
#         [ 20, 127, 199]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.8446000012772856, 'inference': 61.73619999935909, 'postprocess': 0.5757999988418305}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        ...,
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 31, 113, 179],
#         [ 28, 112, 184],
#         [ 28, 112, 184]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 27, 112, 181],
#         [ 22, 112, 187],
#         [ 22, 112, 187]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 27, 112, 181],
#         [ 22, 112, 187],
#         [ 22, 112, 187]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.5909000012470642, 'inference': 58.4859000009601, 'postprocess': 1.319099999818718}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        ...,
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 66,  64,  42],
#         [ 66,  64,  42],
#         [ 66,  64,  42]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 66,  64,  42],
#         [ 66,  64,  42],
#         [ 66,  64,  42]],
#
#        [[ 50,  51,  24],
#         [ 50,  51,  24],
#         [ 50,  52,  23],
#         ...,
#         [ 66,  64,  42],
#         [ 66,  64,  42],
#         [ 66,  64,  42]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.6030000006139744, 'inference': 62.39409999943746, 'postprocess': 0.5031999990023905}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        ...,
#
#        [[ 50,  50,  26],
#         [ 50,  50,  26],
#         [ 50,  51,  24],
#         ...,
#         [ 69,  67,  43],
#         [ 71,  68,  41],
#         [ 72,  69,  42]],
#
#        [[ 51,  51,  27],
#         [ 51,  51,  27],
#         [ 51,  52,  25],
#         ...,
#         [ 69,  67,  43],
#         [ 71,  68,  41],
#         [ 72,  69,  42]],
#
#        [[ 51,  51,  27],
#         [ 51,  51,  27],
#         [ 51,  52,  25],
#         ...,
#         [ 69,  67,  43],
#         [ 71,  68,  41],
#         [ 72,  69,  42]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.8244000002596295, 'inference': 58.88939999931608, 'postprocess': 1.0815000005095499}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [187, 176, 151],
#         [191, 179, 157],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 51,  51,  29],
#         [ 52,  52,  30],
#         [ 53,  54,  27],
#         ...,
#         [  3,  78,  64],
#         [  5,  77,  64],
#         [  5,  77,  64]],
#
#        [[ 52,  52,  30],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  5,  77,  64],
#         [  5,  77,  64],
#         [  5,  77,  64]],
#
#        [[ 52,  52,  30],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  5,  77,  64],
#         [  5,  77,  64],
#         [  4,  76,  63]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.5572000011161435, 'inference': 62.45099999978265, 'postprocess': 0.5588999993051402}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 98,  86,  66],
#         [ 98,  86,  66],
#         [ 98,  86,  66],
#         ...,
#         [187, 176, 151],
#         [191, 179, 157],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 51,  51,  29],
#         [ 52,  52,  30],
#         [ 53,  54,  27],
#         ...,
#         [  3,  78,  64],
#         [  5,  77,  64],
#         [  5,  77,  64]],
#
#        [[ 52,  52,  30],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  5,  77,  64],
#         [  5,  77,  64],
#         [  5,  77,  64]],
#
#        [[ 52,  52,  30],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  5,  77,  64],
#         [  5,  77,  64],
#         [  4,  76,  63]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.4922999998816522, 'inference': 59.6229000002495, 'postprocess': 0.5238000012468547}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [188, 177, 152],
#         [192, 180, 158],
#         [192, 180, 158]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [187, 176, 151],
#         [191, 179, 157],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 52,  52,  30],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  8,  94,  82],
#         [  8,  94,  82],
#         [  8,  94,  82]],
#
#        [[ 53,  53,  31],
#         [ 53,  53,  31],
#         [ 53,  54,  27],
#         ...,
#         [  8,  94,  82],
#         [  8,  94,  82],
#         [  8,  94,  82]],
#
#        [[ 53,  53,  31],
#         [ 54,  54,  32],
#         [ 53,  54,  27],
#         ...,
#         [  8,  94,  82],
#         [  8,  94,  82],
#         [  8,  94,  82]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.4627000000473345, 'inference': 59.3858000011096, 'postprocess': 0.9234000008291332}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 97,  88,  67],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [191, 179, 157]],
#
#        [[ 97,  88,  67],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [192, 180, 158]],
#
#        [[ 97,  88,  67],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [183, 172, 147],
#         [189, 177, 155],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 52,  52,  28],
#         [ 52,  52,  28],
#         [ 53,  54,  27],
#         ...,
#         [ 11, 107,  98],
#         [ 11, 107,  98],
#         [ 11, 107,  98]],
#
#        [[ 53,  53,  29],
#         [ 53,  53,  29],
#         [ 53,  54,  27],
#         ...,
#         [ 10, 106,  97],
#         [ 10, 106,  97],
#         [ 10, 106,  97]],
#
#        [[ 53,  53,  29],
#         [ 53,  53,  29],
#         [ 53,  54,  27],
#         ...,
#         [ 10, 106,  97],
#         [ 10, 106,  97],
#         [ 10, 106,  97]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.7024999997374834, 'inference': 60.00549999953364, 'postprocess': 0.5031000000599306}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [191, 179, 157]],
#
#        [[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [192, 180, 158]],
#
#        [[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [183, 172, 147],
#         [189, 177, 155],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 52,  52,  28],
#         [ 52,  52,  28],
#         [ 53,  54,  27],
#         ...,
#         [ 20, 117, 106],
#         [ 20, 117, 106],
#         [ 20, 117, 106]],
#
#        [[ 53,  53,  29],
#         [ 53,  53,  29],
#         [ 53,  54,  27],
#         ...,
#         [ 20, 117, 106],
#         [ 20, 117, 106],
#         [ 20, 117, 106]],
#
#        [[ 53,  53,  29],
#         [ 53,  53,  29],
#         [ 53,  54,  27],
#         ...,
#         [ 20, 117, 106],
#         [ 20, 117, 106],
#         [ 20, 117, 106]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.438600000255974, 'inference': 62.25009999980102, 'postprocess': 0.4939999998896383}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 96,  87,  66],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [190, 178, 156]],
#
#        [[ 97,  88,  67],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [191, 179, 157]],
#
#        [[ 97,  88,  67],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [183, 172, 147],
#         [189, 177, 155],
#         [190, 178, 156]],
#
#        ...,
#
#        [[ 52,  53,  26],
#         [ 52,  53,  26],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]],
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]],
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.4145999994070735, 'inference': 59.118600000147126, 'postprocess': 0.496299999213079}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [191, 179, 157]],
#
#        [[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [186, 175, 150],
#         [190, 178, 156],
#         [192, 180, 158]],
#
#        [[ 96,  87,  66],
#         [ 96,  87,  66],
#         [ 97,  88,  67],
#         ...,
#         [183, 172, 147],
#         [189, 177, 155],
#         [191, 179, 157]],
#
#        ...,
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 53,  55,  26],
#         ...,
#         [ 37, 130, 109],
#         [ 37, 130, 109],
#         [ 37, 130, 109]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 2.307700000528712, 'inference': 62.2055999992881, 'postprocess': 0.5039000006945571}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [190, 177, 152],
#         [193, 179, 157],
#         [193, 179, 157]],
#
#        [[101,  89,  69],
#         [101,  89,  69],
#         [101,  89,  69],
#         ...,
#         [190, 177, 152],
#         [193, 179, 157],
#         [194, 180, 158]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [189, 176, 151],
#         [193, 179, 157],
#         [194, 180, 158]],
#
#        ...,
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 42, 137, 111],
#         [ 42, 137, 111],
#         [ 42, 137, 111]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 53,  55,  26],
#         ...,
#         [ 42, 137, 111],
#         [ 42, 137, 111],
#         [ 42, 137, 111]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 53,  55,  26],
#         ...,
#         [ 42, 137, 111],
#         [ 42, 137, 111],
#         [ 42, 137, 111]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 2.523799999835319, 'inference': 62.0227999988856, 'postprocess': 0.49949999993259553}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [192, 179, 154],
#         [193, 179, 157],
#         [193, 179, 157]],
#
#        [[101,  89,  69],
#         [101,  89,  69],
#         [101,  89,  69],
#         ...,
#         [192, 179, 154],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [191, 178, 153],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        ...,
#
#        [[ 52,  53,  26],
#         [ 52,  53,  26],
#         [ 53,  55,  26],
#         ...,
#         [ 49, 141, 117],
#         [ 48, 140, 116],
#         [ 48, 140, 116]],
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 49, 141, 117],
#         [ 48, 140, 116],
#         [ 48, 140, 116]],
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 49, 141, 117],
#         [ 48, 140, 116],
#         [ 48, 140, 116]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.512900000307127, 'inference': 60.718000000633765, 'postprocess': 0.5227999990893295}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [192, 179, 154],
#         [193, 179, 157],
#         [194, 180, 158]],
#
#        [[100,  91,  70],
#         [ 99,  90,  69],
#         [ 99,  90,  69],
#         ...,
#         [192, 179, 154],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        [[ 99,  90,  69],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [191, 178, 153],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        ...,
#
#        [[ 53,  55,  26],
#         [ 53,  55,  26],
#         [ 53,  55,  26],
#         ...,
#         [ 52, 145, 124],
#         [ 52, 145, 124],
#         [ 52, 145, 124]],
#
#        [[ 53,  55,  26],
#         [ 53,  55,  26],
#         [ 53,  55,  26],
#         ...,
#         [ 51, 144, 123],
#         [ 51, 144, 123],
#         [ 51, 144, 123]],
#
#        [[ 53,  55,  26],
#         [ 53,  55,  26],
#         [ 53,  55,  26],
#         ...,
#         [ 51, 144, 123],
#         [ 51, 144, 123],
#         [ 51, 144, 123]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.4068999989831354, 'inference': 59.57320000015898, 'postprocess': 0.8997000004455913}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [191, 178, 153],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        [[100,  91,  70],
#         [ 99,  90,  69],
#         [ 99,  90,  69],
#         ...,
#         [190, 177, 152],
#         [194, 180, 158],
#         [193, 179, 157]],
#
#        [[ 99,  90,  69],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [188, 175, 150],
#         [192, 178, 156],
#         [193, 179, 157]],
#
#        ...,
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 54,  56,  27],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 54,  56,  27],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.8440000003465684, 'inference': 59.00300000030256, 'postprocess': 0.5193999986659037}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [191, 178, 153],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        [[100,  91,  70],
#         [ 99,  90,  69],
#         [ 99,  90,  69],
#         ...,
#         [190, 177, 152],
#         [194, 180, 158],
#         [193, 179, 157]],
#
#        [[ 99,  90,  69],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [188, 175, 150],
#         [192, 178, 156],
#         [193, 179, 157]],
#
#        ...,
#
#        [[ 53,  54,  27],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 54,  56,  27],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 54,  56,  27],
#         ...,
#         [ 46, 148, 127],
#         [ 46, 148, 127],
#         [ 46, 148, 127]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.3536999995267252, 'inference': 66.50989999980084, 'postprocess': 0.5457000006572343}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 96,  87,  66],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [191, 178, 153],
#         [194, 180, 158],
#         [194, 180, 158]],
#
#        [[100,  91,  70],
#         [ 99,  90,  69],
#         [ 99,  90,  69],
#         ...,
#         [190, 177, 152],
#         [194, 180, 158],
#         [193, 179, 157]],
#
#        [[ 99,  90,  69],
#         [ 97,  88,  67],
#         [ 97,  88,  67],
#         ...,
#         [188, 175, 150],
#         [192, 178, 156],
#         [193, 179, 157]],
#
#        ...,
#
#        [[ 54,  55,  28],
#         [ 53,  54,  27],
#         [ 53,  55,  26],
#         ...,
#         [ 82, 168, 148],
#         [ 81, 167, 147],
#         [ 81, 167, 147]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 54,  56,  27],
#         ...,
#         [ 82, 168, 148],
#         [ 81, 167, 147],
#         [ 81, 167, 147]],
#
#        [[ 54,  55,  28],
#         [ 54,  55,  28],
#         [ 53,  55,  26],
#         ...,
#         [ 82, 168, 148],
#         [ 81, 167, 147],
#         [ 81, 167, 147]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# ...
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [184, 175, 152],
#         [186, 179, 156],
#         [187, 180, 157]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [181, 172, 149],
#         [183, 176, 153],
#         [185, 178, 155]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [182, 174, 148],
#         [184, 175, 154],
#         [185, 176, 155]],
#
#        ...,
#
#        [[ 52,  54,  25],
#         [ 52,  54,  25],
#         [ 50,  53,  21],
#         ...,
#         [ 51,  48,  15],
#         [ 51,  48,  15],
#         [ 51,  48,  15]],
#
#        [[ 54,  56,  27],
#         [ 51,  53,  24],
#         [ 50,  53,  21],
#         ...,
#         [ 53,  50,  17],
#         [ 53,  50,  17],
#         [ 53,  50,  17]],
#
#        [[ 53,  55,  26],
#         [ 51,  53,  24],
#         [ 50,  53,  21],
#         ...,
#         [ 53,  50,  17],
#         [ 53,  50,  17],
#         [ 53,  50,  17]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.315400000748923, 'inference': 59.213399999862304, 'postprocess': 0.8221999996749219}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [182, 173, 150],
#         [185, 178, 155],
#         [186, 179, 156]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 171, 148],
#         [182, 175, 152],
#         [185, 178, 155]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 172, 146],
#         [182, 173, 152],
#         [185, 176, 155]],
#
#        ...,
#
#        [[ 54,  54,  25],
#         [ 54,  54,  25],
#         [ 50,  53,  21],
#         ...,
#         [ 56,  51,  23],
#         [ 53,  51,  22],
#         [ 53,  51,  22]],
#
#        [[ 56,  56,  27],
#         [ 53,  53,  24],
#         [ 50,  53,  21],
#         ...,
#         [ 56,  51,  23],
#         [ 53,  51,  22],
#         [ 53,  51,  22]],
#
#        [[ 55,  55,  26],
#         [ 53,  53,  24],
#         [ 50,  53,  21],
#         ...,
#         [ 57,  52,  24],
#         [ 54,  52,  23],
#         [ 54,  52,  23]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.350500000626198, 'inference': 59.868500000447966, 'postprocess': 0.5427000014606165}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [182, 173, 150],
#         [186, 179, 156],
#         [187, 180, 157]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 171, 148],
#         [183, 176, 153],
#         [186, 179, 156]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 172, 146],
#         [184, 175, 154],
#         [186, 177, 156]],
#
#        ...,
#
#        [[ 52,  54,  25],
#         [ 52,  54,  25],
#         [ 52,  53,  21],
#         ...,
#         [ 70,  66,  42],
#         [ 70,  66,  42],
#         [ 70,  66,  42]],
#
#        [[ 54,  56,  27],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 69,  65,  41],
#         [ 69,  65,  41],
#         [ 69,  65,  41]],
#
#        [[ 53,  55,  26],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 69,  65,  41],
#         [ 69,  65,  41],
#         [ 69,  65,  41]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.3954000005469425, 'inference': 59.21640000087791, 'postprocess': 0.5340999996406026}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [182, 173, 150],
#         [185, 178, 155],
#         [186, 179, 156]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 171, 148],
#         [182, 175, 152],
#         [185, 178, 155]],
#
#        [[ 99,  87,  67],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 172, 146],
#         [182, 173, 152],
#         [185, 176, 155]],
#
#        ...,
#
#        [[ 52,  54,  25],
#         [ 52,  54,  25],
#         [ 52,  53,  21],
#         ...,
#         [ 70,  66,  42],
#         [ 70,  66,  42],
#         [ 70,  66,  42]],
#
#        [[ 54,  56,  27],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 69,  65,  41],
#         [ 69,  65,  41],
#         [ 69,  65,  41]],
#
#        [[ 53,  55,  26],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 69,  65,  41],
#         [ 69,  65,  41],
#         [ 69,  65,  41]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.770599999872502, 'inference': 59.258700001009856, 'postprocess': 0.4939999998896383}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [101,  89,  69],
#         [ 99,  87,  67],
#         ...,
#         [182, 173, 150],
#         [185, 178, 155],
#         [186, 179, 156]],
#
#        [[101,  89,  69],
#         [101,  89,  69],
#         [ 99,  87,  67],
#         ...,
#         [180, 171, 148],
#         [182, 175, 152],
#         [185, 178, 155]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 172, 146],
#         [182, 173, 152],
#         [185, 176, 155]],
#
#        ...,
#
#        [[ 52,  54,  25],
#         [ 52,  54,  25],
#         [ 52,  53,  21],
#         ...,
#         [ 61,  61,  37],
#         [ 65,  63,  41],
#         [ 65,  63,  41]],
#
#        [[ 54,  56,  27],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 61,  61,  37],
#         [ 65,  63,  41],
#         [ 65,  63,  41]],
#
#        [[ 53,  55,  26],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [ 61,  61,  37],
#         [ 65,  63,  41],
#         [ 65,  63,  41]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 1.399900000251364, 'inference': 57.73810000027879, 'postprocess': 1.1181999998370884}
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[101,  89,  69],
#         [101,  89,  69],
#         [ 99,  87,  67],
#         ...,
#         [182, 173, 150],
#         [186, 179, 156],
#         [187, 180, 157]],
#
#        [[101,  89,  69],
#         [101,  89,  69],
#         [ 99,  87,  67],
#         ...,
#         [180, 171, 148],
#         [183, 176, 153],
#         [186, 179, 156]],
#
#        [[101,  89,  69],
#         [ 99,  87,  67],
#         [ 99,  87,  67],
#         ...,
#         [180, 172, 146],
#         [184, 175, 154],
#         [186, 177, 156]],
#
#        ...,
#
#        [[ 53,  55,  26],
#         [ 52,  54,  25],
#         [ 52,  53,  21],
#         ...,
#         [  5,  65, 135],
#         [  3,  63, 133],
#         [  3,  63, 133]],
#
#        [[ 54,  56,  27],
#         [ 51,  53,  24],
#         [ 52,  53,  21],
#         ...,
#         [  7,  65, 135],
#         [  5,  63, 133],
#         [  5,  63, 133]],
#
#        [[ 53,  55,  26],
#         [ 52,  54,  25],
#         [ 52,  53,  21],
#         ...,
#         [  5,  63, 133],
#         [  3,  61, 131],
#         [  3,  61, 131]]], shape=(1080, 1920, 3), dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio3\\video.mov'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio3\\runs\\detect\\track'
# semantic_mask: None
# speed: {'preprocess': 2.10739999965881, 'inference': 60.200399999303045, 'postprocess': 0.4934999997203704}

# %%
writer = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 20, (2048, 1080))

for r in results:
    writer.write(r.plot())

# %% [markdown]
# ### Referência
#
# - https://docs.ultralytics.com/modes/track/
