# %% [markdown]
# ## Desafio 4 da Trilha de Visão Computacional
#
# Solução simples para reconhecimento de poses
#
# Aluna: Liah Colins

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install ultralytics matplotlib torch

# %%
import ultralytics
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ### Processar Dados

# %%
model = ultralytics.YOLO("yolo11n-pose.pt")

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

results = model("desafio_4.jpeg")
# Out:
# image 1/1 c:\Liah\Nexvisual\Desafios\Desafio4\desafio_4.jpeg: 288x640 5 persons, 60.4ms
# Speed: 2.4ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)

# %% [markdown]
# ### Visualizar Resultados

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt

print(results[0])

im_array = results[0].plot()
rgb_img = cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_img)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'person'}
# obb: None
# orig_img: array([[[119, 140, 131],
#         [118, 139, 130],
#         [120, 139, 130],
#         ...,
#         [183, 220, 204],
#         [194, 228, 211],
#         [223, 246, 231]],
#
#        [[120, 139, 130],
#         [118, 137, 128],
#         [118, 137, 128],
#         ...,
#         [200, 233, 219],
#         [190, 226, 210],
#         [199, 228, 212]],
#
#        [[118, 137, 128],
#         [117, 136, 127],
#         [117, 136, 127],
#         ...,
#         [219, 247, 241],
#         [204, 236, 225],
#         [201, 227, 213]],
#
#        ...,
#
#        [[113, 134, 165],
#         [113, 134, 162],
#         [ 98, 115, 141],
#         ...,
#         [128, 121,  58],
#         [128, 124,  59],
#         [118, 115,  47]],
#
#        [[107, 128, 159],
#         [102, 123, 151],
#         [ 98, 115, 141],
#         ...,
#         [116, 107,  44],
#         [127, 120,  57],
#         [128, 124,  59]],
#
#        [[ 87, 107, 138],
#         [ 79,  98, 125],
#         [ 80,  97, 123],
#         ...,
#         [107,  97,  37],
#         [120, 111,  48],
#         [125, 119,  54]]], shape=(2691, 6000, 3), dtype=uint8)
# orig_shape: (2691, 6000)
# path: 'c:\\Liah\\Nexvisual\\Desafios\\Desafio4\\desafio_4.jpeg'
# probs: None
# save_dir: 'C:\\Liah\\Nexvisual\\Desafios\\Desafio4\\runs\\pose\\predict'
# semantic_mask: None
# speed: {'preprocess': 2.3825999996915925, 'inference': 60.420499999963795, 'postprocess': 1.027500000418513}

# %% [markdown]
# ### Referência
#
# - https://docs.ultralytics.com/tasks/pose
